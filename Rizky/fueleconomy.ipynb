# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df = pd.read_csv("fuel_econ.csv")
df.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# 0   79    0  16.4596  20.2988  22.5568   30.1798  18.7389  471        4
# 1   94    0  21.8706  26.9770  31.0367   42.4936  25.2227  349        6
# 2   94    0  17.4935  21.2000  26.5716   35.1000  20.6716  429        5
# 3   94    0  16.9415  20.5000  25.2190   33.5000  19.8774  446        5
# 4    0   95  24.7726  31.9796  35.5340   51.8816  28.6813  310        8
#
#    ghgScore
# 0         4
# 1         6
# 2         5
# 3         5
# 4         8

# %%
fuelecon = df[['id', 'make', 'model', 'year', 'VClass', 'drive', 'fuelType', 
               'feScore']].copy()

# %%
fuelecon.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive          fuelType  feScore
# 0    All-Wheel Drive  Premium Gasoline        4
# 1  Front-Wheel Drive  Premium Gasoline        6
# 2  Front-Wheel Drive  Premium Gasoline        5
# 3    All-Wheel Drive  Premium Gasoline        5
# 4  Front-Wheel Drive  Regular Gasoline        8

# %%
fuelecon = fuelecon.rename(columns={
    'id': 'ID',
    'make': 'Make',
    'model': 'Model',
    'year': 'Year',
    'VClass': 'Vehicle_Class',
    'drive': 'Drive',
    'fuelType': 'Fuel_Type',
    'feScore': 'Fuel_Economy_Score'
})

# %%
fuelecon['Good Fuel Economy?'] = np.where(fuelecon['Fuel_Economy_Score'] > 6, 'yes', 'no')

# %%
fuelecon.set_index('ID', inplace = True)

# %%
fuelecon.sample(5)
# Out:
#                 Make                 Model  Year    Vehicle_Class  \
# ID
# 35221      Chevrolet                Camaro  2015     Compact Cars
# 37830            Kia               Cadenza  2017       Large Cars
# 32614     Volkswagen                 Jetta  2013     Compact Cars
# 38144  Mercedes-Benz  AMG S63 4matic Coupe  2017     Compact Cars
# 35611     Volkswagen    Beetle Convertible  2015  Subcompact Cars
#
#                    Drive         Fuel_Type  Fuel_Economy_Score  \
# ID
# 35221   Rear-Wheel Drive  Premium Gasoline                   3
# 37830  Front-Wheel Drive  Regular Gasoline                   5
# 32614  Front-Wheel Drive  Premium Gasoline                   7
# 38144      4-Wheel Drive  Premium Gasoline                   3
# 35611  Front-Wheel Drive            Diesel                   8
#
#       Good Fuel Economy?
# ID
# 35221                 no
# 37830                 no
# 32614                yes
# 38144                 no
# 35611                yes

# %%
fuelecon[fuelecon["Model"]== "Mustang Convertible"]
# Out:
#        Make                Model  Year    Vehicle_Class             Drive  \
# ID
# 32248  Ford  Mustang Convertible  2013  Subcompact Cars  Rear-Wheel Drive
# 33430  Ford  Mustang Convertible  2014  Subcompact Cars  Rear-Wheel Drive
# 35860  Ford  Mustang Convertible  2015  Subcompact Cars  Rear-Wheel Drive
# 35861  Ford  Mustang Convertible  2015  Subcompact Cars  Rear-Wheel Drive
# 36879  Ford  Mustang Convertible  2016  Subcompact Cars  Rear-Wheel Drive
# 36883  Ford  Mustang Convertible  2016  Subcompact Cars  Rear-Wheel Drive
# 37575  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37579  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37584  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37585  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 39644  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
# 39647  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
# 39651  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
#
#               Fuel_Type  Fuel_Economy_Score Good Fuel Economy?
# ID
# 32248  Regular Gasoline                   6                 no
# 33430  Regular Gasoline                   6                 no
# 35860  Regular Gasoline                   4                 no
# 35861  Regular Gasoline                   6                 no
# 36879  Regular Gasoline                   5                 no
# 36883  Regular Gasoline                   4                 no
# 37575  Regular Gasoline                   5                 no
# 37579  Regular Gasoline                   3                 no
# 37584  Regular Gasoline                   5                 no
# 37585  Regular Gasoline                   3                 no
# 39644  Regular Gasoline                   5                 no
# 39647  Regular Gasoline                   5                 no
# 39651  Regular Gasoline                   3                 no

# %%
fuelecon = fuelecon.drop_duplicates(subset=['Model'])
# Out:
#              Make           Model  Year    Vehicle_Class              Drive  \
# ID
# 32204      Nissan            GT-R  2013  Subcompact Cars    All-Wheel Drive
# 32205  Volkswagen              CC  2013     Compact Cars  Front-Wheel Drive
# 32207  Volkswagen      CC 4motion  2013     Compact Cars    All-Wheel Drive
# 32208   Chevrolet  Malibu eAssist  2013     Midsize Cars  Front-Wheel Drive
# 32209       Lexus          GS 350  2013     Midsize Cars   Rear-Wheel Drive
# ...           ...             ...   ...              ...                ...
# 39865         BMW    X2 xDrive28i  2018     Midsize Cars    All-Wheel Drive
# 39866       Lexus         LS 500h  2018     Midsize Cars   Rear-Wheel Drive
# 39867       Lexus     LS 500h AWD  2018     Midsize Cars    All-Wheel Drive
# 39900       Lexus          LS 500  2018     Midsize Cars   Rear-Wheel Drive
# 39901       Lexus      LS 500 AWD  2018     Midsize Cars    All-Wheel Drive
#
#               Fuel_Type  Fuel_Economy_Score Good Fuel Economy?
# ID
# 32204  Premium Gasoline                   4                 no
# 32205  Premium Gasoline                   6                 no
# 32207  Premium Gasoline                   5                 no
# 32208  Regular Gasoline                   8                yes
# 32209  Premium Gasoline                   6                 no
# ...                 ...                 ...                ...
# 39865  Premium Gasoline                   5                 no
# 39866  Premium Gasoline                   6                 no
# 39867  Premium Gasoline                   5                 no
# 39900  Premium Gasoline                   5                 no
# 39901  Premium Gasoline                   4                 no
#
# [769 rows x 8 columns]

# %%
fuelecon[fuelecon["Model"]== "Mustang Convertible"]
# Out:
#        Make                Model  Year    Vehicle_Class             Drive  \
# ID
# 32248  Ford  Mustang Convertible  2013  Subcompact Cars  Rear-Wheel Drive
# 33430  Ford  Mustang Convertible  2014  Subcompact Cars  Rear-Wheel Drive
# 35860  Ford  Mustang Convertible  2015  Subcompact Cars  Rear-Wheel Drive
# 35861  Ford  Mustang Convertible  2015  Subcompact Cars  Rear-Wheel Drive
# 36879  Ford  Mustang Convertible  2016  Subcompact Cars  Rear-Wheel Drive
# 36883  Ford  Mustang Convertible  2016  Subcompact Cars  Rear-Wheel Drive
# 37575  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37579  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37584  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 37585  Ford  Mustang Convertible  2017  Subcompact Cars  Rear-Wheel Drive
# 39644  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
# 39647  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
# 39651  Ford  Mustang Convertible  2018  Subcompact Cars  Rear-Wheel Drive
#
#               Fuel_Type  Fuel_Economy_Score Good Fuel Economy?
# ID
# 32248  Regular Gasoline                   6                 no
# 33430  Regular Gasoline                   6                 no
# 35860  Regular Gasoline                   4                 no
# 35861  Regular Gasoline                   6                 no
# 36879  Regular Gasoline                   5                 no
# 36883  Regular Gasoline                   4                 no
# 37575  Regular Gasoline                   5                 no
# 37579  Regular Gasoline                   3                 no
# 37584  Regular Gasoline                   5                 no
# 37585  Regular Gasoline                   3                 no
# 39644  Regular Gasoline                   5                 no
# 39647  Regular Gasoline                   5                 no
# 39651  Regular Gasoline                   3                 no

# %%
rds_connection_string = "postgres:postgres@localhost:5432/norwaycars"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['fueleconomy']

# %%
fuelecon.to_sql(name='fueleconomy', con=engine, if_exists='replace', index=True)

# %%
with engine.connect() as con:
    con.execute('ALTER TABLE fueleconomy ADD PRIMARY KEY ("Model", "Year");')
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UniqueViolation: could not create unique index "fueleconomy_pkey"
# DETAIL:  Key ("Model", "Year")=(Mustang Convertible, 2015) is duplicated.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-65-86c3a4575d5b> in <module>
#       1 with engine.connect() as con:
# ----> 2     con.execute('ALTER TABLE fueleconomy ADD PRIMARY KEY ("Model", "Year");')
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.UniqueViolation) could not create unique index "fueleconomy_pkey"
# DETAIL:  Key ("Model", "Year")=(Mustang Convertible, 2015) is duplicated.
#
# [SQL: ALTER TABLE fueleconomy ADD PRIMARY KEY ("Model", "Year");]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
